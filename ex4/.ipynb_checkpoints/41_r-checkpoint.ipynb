# %% [markdown]
# # 4.1

# %%
import numpy as np
import matplotlib.pyplot as pp
# %matplotlib inline

data = np.array([[-1., -0.1], [0.3, 0.5], [2., 0.5]])
print data  # [X|Yt]

X = data[:,0]
Yt = data[:,1]
# Out:
# [[-1.  -0.1]
#  [ 0.3  0.5]
#  [ 2.   0.5]]

# %%
def plot_init(X,Yt):
    x_min, x_max = np.min(X)-.5, np.max(X)+.5
    y_min, y_max = np.min(Yt)-.5, np.max(Yt)+.5
    
    pp.figure(figsize=(16,8))

    pp.subplot(1,2,1)
    pp.scatter(X,Yt)
    
    pp.xlim(x_min, x_max)
    pp.ylim(y_min, y_max)
    pp.ylabel("y")
    pp.xlabel("x")
    
    pp.subplot(1,2,2)
    pp.xlim(0,.5)
    pp.ylim(0,.5)
    pp.grid()
    return

def plot_line_and_weights(X, w, color="grey"):
    x_min, x_max = np.min(X)-.5, np.max(X)+.5

    Xline = np.linspace(x_min, x_max, 100)
    Xline = np.vstack([np.ones(Xline.shape), Xline])

    pp.subplot(1,2,1)
    pp.plot(Xline[1,:], (w).dot(Xline), color=color)

    pp.subplot(1,2,2)
    pp.scatter(w[0], w[1], c=color, marker='x')
    return

# %% [markdown]
# ## (a) Steepest Gradient Descent

# %%
def gradient_descent(X, Yt, eta, w_start=np.random.random(2)*2. - 1, draw=False):
    if draw:
        plot_init(X, Yt)
        
    w = w_start  # [w_bias, w1]
    X = np.vstack([np.ones(X.shape), X])  # stack bias on
    # print w, "w"
    # print X, "X"
    Y = wTx = w.dot(X)
    Ew = ((Y - Yt)**2).sum(0)/2.
    
    print "%3s %10s %10s %10s"%("i", "w0", "w1", "E(w)")

    for i in range(1000):        
        # calc gradient
        H = X.dot(X.T)
        # print H, "H"
        b = -X.dot(Yt.T)
        # print b, "b"
        g = H.dot(w) + b
        # print g, "g"
        
        w_new = w - eta*g
        
        # calc output
        Y = wTx = w_new.dot(X)

        # calc sum of squares error
        # Ew = (( Y-Yt ).dot( (Y-Yt).T ))/2.
        Ew_new = ((Y-Yt)**2).sum(0)/2.
        # print Ew, "Ew"
        
        print "%3i %10f %10f %10f"%(i, w[0], w[1], Ew_new)

        if draw:
            plot_line_and_weights(X, w_new)
        
        if np.abs(Ew - Ew_new)/Ew < 10**-4:
            break;
        else:
            w = w_new
            Ew = Ew_new

    if draw:
        plot_line_and_weights(X, w, color="blue")
    
    return

gradient_descent(X, Yt, .5/float(len(X)), draw=True)
# Out:
#   i         w0         w1       E(w)
#   0  -0.279063  -0.350632   0.061439
#   1   0.086439   0.215618   0.045573
#   2   0.146502   0.222307   0.040953
#   3   0.175085   0.210308   0.039271
#   4   0.191976   0.202295   0.038658
#   5   0.202157   0.197420   0.038435
#   6   0.208304   0.194475   0.038353
#   7   0.212016   0.192696   0.038323
#   8   0.214257   0.191622   0.038313
#   9   0.215610   0.190974   0.038309
#  10   0.216428   0.190582   0.038307

# %% [markdown]
# ## (b) Line Search

# %%
def line_search(X, Yt, w_start=np.random.random(2)*2. - 1, draw=False):
    if draw:
        plot_init(X, Yt)
        
    w = w_start  # [w_bias, w1]
    X = np.vstack([np.ones(X.shape), X])  # stack bias on
    # print w, "w"
    # print X, "X"
    Y = wTx = w.dot(X)
    Ew = ((Y - Yt)**2).sum(0)/2.
    
    print "%3s %10s %10s %10s"%("i", "w0", "w1", "E(w)")

    for i in range(1000):        
        # calc gradient
        H = X.dot(X.T)
        # print H, "H"
        b = -X.dot(Yt.T)
        # print b, "b"
        g = H.dot(w) + b
        # print g, "g"
        
        alpha = -( g.T.dot(g) )/( g.T.dot(H).dot(g) )
        w_new = w + alpha*g 
        
        # calc output
        Y = wTx = w_new.dot(X)

        # calc sum of squares error
        # Ew = (( Y-Yt ).dot( (Y-Yt).T ))/2.
        Ew_new = ((Y-Yt)**2).sum(0)/2.
        # print Ew, "Ew"
        
        print "%3i %10f %10f %10f"%(i, w[0], w[1], Ew_new)

        if draw:
            plot_line_and_weights(X, w_new)
        
        if np.abs(Ew - Ew_new)/Ew < 10**-4:
            break;
        else:
            w = w_new
            Ew = Ew_new

    if draw:
        plot_line_and_weights(X, w, color="blue")
    
    return

line_search(X, Yt, draw=True)
# Out:
#   i         w0         w1       E(w)
#   0  -0.754419   0.358432   0.230268
#   1   0.032113   0.476917   0.067167
#   2   0.071521   0.215311   0.042646
#   3   0.189775   0.233125   0.038959
#   4   0.195700   0.193793   0.038404
#   5   0.213479   0.196471   0.038321
#   6   0.214369   0.190558   0.038309
#   7   0.217042   0.190960   0.038307

# %% [markdown]
# ## (c) Conjugate Gradient

# %%
def conjugate_gradient(X, Yt, w_start=np.random.random(2)*2. - 1, draw=False):
    if draw:
        plot_init(X, Yt)
    
    w = w_start  # [w_bias, w1]
    X = np.vstack([np.ones(X.shape), X])  # stack bias on
    # print w, "w"
    # print X, "X"
    
    print "%3s %10s %10s %10s %s"%("i", "w0", "w1", "E(w)", "Y")

    # calc gradient for step 1
    H = X.dot(X.T)
    # print H, "H"
    b = -X.dot(Yt.T)
    # print b, "b"
    g = H.dot(w) + b
    # print g, "g"
    
    w = -g  # weights
    d = -g  # direction
    
    Y = w.T.dot(X)
    # calc sum of squares error
    # Ew = (( Y-Yt ).dot( (Y-Yt).T ))/2.
    Ew = ((Y-Yt)**2).sum(0)/2.
    # print Ew, "Ew"
    
    for i in range(1000):
        # minimize E along d
        alpha = -( d.T.dot(g) )/( d.T.dot(H).dot(d) )
        w_new = w + alpha*d
        
        Y = w_new.T.dot(X)
        # calc sum of squares error
        # Ew = (( Y-Yt ).dot( (Y-Yt).T ))/2.
        Ew_new = ((Y - Yt)**2).sum(0)/2.
        # print Ew, "Ew"

        print "%3i %10f %10f %10f %s"%(i, w[0], w[1], Ew, str(Y))
        
        if draw:
            plot_line_and_weights(X, w_new)
        
        if np.abs(Ew - Ew_new)/Ew < 10**-4:
            break;
        else:
            g_new = H.dot(w_new) + b
            beta = -( g_new.T.dot(g_new) )/( g.T.dot(g) )
            d_new = g_new + beta*d
            g = g_new
            d = d_new
            w = w_new
            Ew = Ew_new
        
    if draw:
        plot_line_and_weights(X, w, "blue")
    
    return

conjugate_gradient(X, Yt, draw=True)
# Out:
#   i         w0         w1       E(w) Y
#   0   1.286356  -2.947621  22.446825 [ 5.34744524  0.50780764 -5.82094922]
#   1   1.624647  -3.722798  34.814560 [-0.63582934 -0.46576891 -0.24338219]
#   2  -0.505014   0.130816   0.886220 [-0.79765405 -0.19650571  0.58961136]
#   3  -0.335232   0.462422   0.489936 [-0.33492924 -0.12464544  0.15034107]
#   4  -0.173172   0.161757   0.283818 [-0.45735854 -0.04025441  0.50518946]
#   5  -0.136509   0.320849   0.209803 [-0.19250073  0.01186277  0.27910735]
#   6  -0.035298   0.157203   0.147814 [-0.28991447  0.04716918  0.48797086]
#   7  -0.030619   0.259295   0.120634 [-0.10422394  0.09398238  0.35317525]
#   8   0.048242   0.152466   0.093213 [-0.18472385  0.10875821  0.49254245]
#   9   0.041032   0.225755   0.080152 [-0.04386016  0.15287216  0.4101375 ]
#  10   0.107472   0.151333   0.065862 [-0.11086676  0.15720983  0.50777152]
#  11   0.095346   0.206213   0.058842 [-0.0021919   0.19852019  0.46098985]
#  12   0.152202   0.154394   0.050989 [-0.05657602  0.19740838  0.52954184]
#  13   0.138797   0.195373   0.047160 [ 0.0240289   0.23432881  0.50933639]
#  14   0.185798   0.161769   0.043026 [-0.01670932  0.2311666   0.55531204]
#  15   0.173964   0.190674   0.041134 [ 0.03519612  0.26028668  0.55463588]
#  16   0.208343   0.173147   0.039363 [ 0.01106925  0.2581492   0.58125374]
#  17   0.201131   0.190061   0.038715 [ 0.03183351  0.27342956  0.58936285]
#  18   0.217677   0.185843   0.038350 [ 0.02660891  0.27375176  0.59693855]
#  19   0.216719   0.190110   0.038308 [ 0.02739064  0.27462089  0.59792198]

# %%
w_start = np.random.rand(2)*2. - 1

print "gradient descent"
gradient_descent(X, Yt, 0.5/float(len(X)), w_start, draw=True)
pp.suptitle("gradient descent", fontsize=18)

print "line search"
line_search(X, Yt, w_start, draw=True)
pp.suptitle("line search", fontsize=18)

print "conjugate gradient"
conjugate_gradient(X, Yt, w_start, draw=True)
pp.suptitle("conjugate gradient", fontsize=18)
# Out:
# gradient descent
#   i         w0         w1       E(w)
#   0  -0.422747   0.803594   0.346539
#   1  -0.235485   0.421807   0.150508
#   2  -0.059134   0.323329   0.079215
#   3   0.050378   0.270184   0.053222
#   4   0.116649   0.238396   0.043745
#   5   0.156672   0.219216   0.040289
#   6   0.180839   0.207635   0.039029
#   7   0.195432   0.200643   0.038570
#   8   0.204243   0.196421   0.038402
#   9   0.209564   0.193871   0.038341
#  10   0.212777   0.192332   0.038319
#  11   0.214716   0.191402   0.038311
#  12   0.215888   0.190841   0.038308
# line search
#   i         w0         w1       E(w)
#   0  -0.422747   0.803594   0.210775
#   1  -0.115487   0.177155   0.066300
#   2   0.113726   0.289581   0.042850
#   3   0.163597   0.187903   0.039044
#   4   0.200801   0.206151   0.038426
#   5   0.208896   0.189647   0.038326
#   6   0.214935   0.192609   0.038309
#   7   0.216248   0.189930   0.038307
# conjugate gradient
#   i         w0         w1       E(w) Y
#   0   1.123568  -2.290721  14.009521 [ 4.34798727  0.55568023 -4.4034905 ]
#   1   1.430828  -2.917159  21.915955 [-0.54530286 -0.41009419 -0.23328285]
#   2  -0.441296   0.104007   0.782135 [-0.75321711 -0.2050713   0.51173476]
#   3  -0.331566   0.421651   0.461978 [-0.26153991 -0.09419867  0.12463217]
#   4  -0.132816   0.128724   0.260034 [-0.40886314 -0.02878518  0.46823984]
#   5  -0.116495   0.292368   0.188009 [-0.1161021   0.05494395  0.27861955]
#   6   0.015472   0.131574   0.123672 [-0.22750079  0.07809848  0.47772831]
#   7   0.007576   0.235076   0.097377 [-0.02979209  0.14915458  0.38316176]
#   8   0.107859   0.137651   0.070836 [-0.11400098  0.15498001  0.50672438]
#   9   0.092907   0.206908   0.059640 [ 0.01908546  0.21438076  0.46976692]
#  10   0.169313   0.150227   0.048337 [-0.03940395  0.21353694  0.5443058 ]
#  11   0.155166   0.194570   0.043848 [ 0.03722563  0.25657883  0.54342533]
#  12   0.205959   0.168733   0.039985 [ 0.00720755  0.25574059  0.58074533]
#  13   0.198387   0.191179   0.038838 [ 0.03110683  0.27385505  0.59129502]
#  14   0.217836   0.186729   0.038333 [ 0.02750703  0.27452773  0.59755479]
#  15   0.217523   0.190016   0.038306 [ 0.02762703  0.27465934  0.59770159]

# %% [markdown]
# # 4.2

# %%
def plot_result(X, Yt, w):
    x_min, x_max = np.min(X)-.5, np.max(X)+.5
    y_min, y_max = np.min(Yt)-.5, np.max(Yt)+.5
    
    pp.scatter(X[1,:], Yt)
    
    pp.xlim(x_min, x_max)
    pp.ylim(y_min, y_max)
    pp.ylabel("y")
    pp.xlabel("x")
    
    Xline = np.linspace(x_min, x_max, 100)
    Xline = np.vstack([np.ones(Xline.shape), Xline])

    pp.plot(Xline[1,:], (w.T).dot(Xline).T)
    return

def least_squares(X, Yt):
    # minimize E(w)
    # build linear system
    
    X = np.vstack([np.ones(len(X)), X])
    Yt = Yt[:,np.newaxis]
    print Yt, "Yt\n"
    
    A = X.T
    
    # solve Normalgleichungssystem A'Ax = A'b (<=> in our case A'Aw = A'Yt)
    w = np.linalg.solve(A.T.dot(A), A.T.dot(Yt))
    print w.T, "w from Normalungleichungssystem"
    
    pp.figure(figsize=(16,8))
    pp.subplot(1,2,1)
    plot_result(X, Yt, w)
    
    # now again with generalized inverse as per https://en.wikipedia.org/wiki/Generalized_inverse
    A_inv = np.linalg.pinv(A)
    print A_inv.dot(Yt).T - (np.eye(2)-A_inv.dot(A)).dot(np.random.rand(2)), "w from generalized inverse"
    
    return

least_squares(X, Yt)
# Out:
# [[-0.1]
#  [ 0.5]
#  [ 0.5]] Yt
#
# [[ 0.21767305  0.18998527]] w from Normalungleichungssystem
# [[ 0.21767305  0.18998527]] w from generalized inverse
